# %% [markdown]
# # V2.0A 可信度验证体系快速复现
#
# 运行 `run_vv(mode='fast')` 可重建报告、表格和图包。

# %%
from hpm_platform.validation.vv_runner import run_vv
result = run_vv(mode='fast')
result['score']
# Out:
# 可信度评分：91.58，等级：A
# VV-01 8x8均匀矩形阵列远场方向图解析验证: 通过
# VV-02 相位扫描波束指向解析验证: 通过
# VV-03 自由空间Green函数幅相验证: 通过
# VV-04 MUSIC/ESPRIT/PAWR测向基准验证: 通过
# VV-05 MVDR/LCMV约束响应验证: 通过
# VV-06 传播后端一致性与适用性验证: 通过
