# %% [markdown]
# # HPM Digital Twin v0.2 — 相干多径感知快速入口
# 本笔记本调用与命令行相同的可复现工作流。默认使用30次/点的快速配置；正式论文请切换到 `perception_v02_paper.yaml`。

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
from hpm_platform.workflows.perception_v02 import run

# %%
metrics = run(ROOT / 'configs/perception_v02.yaml', ROOT / 'outputs_v02_notebook')
metrics

# %% [markdown]
# 图文报告：`outputs_v02_notebook/perception_v02_report.html`。逐试验数据位于 `monte_carlo_trials.csv`。
