# %% [markdown]
# # HPM Digital Twin V0.8 quickstart
#
# This notebook runs the normalized effect-evaluation workflow and inspects its key outputs. All quantities are dimensionless and uncalibrated.

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
sys.path.insert(0, str(ROOT / 'src'))
from hpm_platform.workflows.effect_twin_v08 import run

# %%
metrics = run(ROOT / 'configs/effect_twin_v08.yaml', ROOT / 'outputs_v08_effect_twin')
metrics['primary_tier'], metrics['run_time_seconds']

# %%
import json
summary = json.loads((ROOT / 'outputs_v08_effect_twin/results_summary.json').read_text())
[row for row in summary['method_summary'] if row['tier'] == summary['primary_tier']]

# %%
from IPython.display import Image, display
display(Image(filename=str(ROOT / 'outputs_v08_effect_twin/04_world_fixed_probability.png')))
display(Image(filename=str(ROOT / 'outputs_v08_effect_twin/29_ea_duty_dynamic_probability.gif')))

# %% [markdown]
# ## Paper-level rerun
#
# Use `configs/effect_twin_v08_paper.yaml` for the larger Monte Carlo configuration. It is intentionally not precomputed in the public package.
