# %% [markdown]
# # HPM Digital Twin v0.1 快速入口
# 运行最小闭环并在 Notebook 中直接查看全部图像。公开基线采用归一化场量与统计响应指标。

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().parent if Path.cwd().name == 'notebooks' else Path.cwd()
sys.path.insert(0, str(ROOT / 'src'))
from hpm_platform.workflows.demo_closed_loop import run
metrics = run(ROOT / 'configs/default.yaml', ROOT / 'outputs')
metrics

# %%
from IPython.display import display, Image
for name in [
    '00_architecture.png', '01_far_field_uv.png', '02_music_spectrum.png',
    '03_receive_suppression.png', '04_near_field_focus.png',
    '05_effect_probability.png'
]:
    display(Image(filename=str(ROOT / 'outputs' / name)))
