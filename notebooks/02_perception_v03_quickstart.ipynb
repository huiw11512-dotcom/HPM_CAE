# %% [markdown]
# # V0.3 PAWR-MUSIC quickstart
# 运行归一化相干多径感知、局部通道异常和宽松先验扫参。

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve().parent if Path.cwd().name == 'notebooks' else Path.cwd().resolve()
sys.path.insert(0, str(ROOT / 'src'))
from hpm_platform.workflows.perception_v03 import run

# %%
metrics = run(ROOT / 'configs/perception_v03.yaml', ROOT / 'outputs_v03_perception')
metrics['monte_carlo']['at_minus8_db_two_faults']

# %% [markdown]
# 自包含报告：`outputs_v03_perception/perception_v03_report_standalone.html`。论文定稿请改用 `configs/perception_v03_paper.yaml`。
