# %% [markdown]
# # HPM-CAE V1.2 多对象约束控场 Quickstart
#
# 本笔记本使用波长尺度几何、归一化标量场和无量纲约束，仅用于算法研究与软件复现。

# %%
from pathlib import Path
import sys
ROOT = Path.cwd().resolve()
if ROOT.name == 'notebooks': ROOT = ROOT.parent
sys.path.insert(0, str(ROOT / 'src'))

from hpm_platform.ui.project_model import CAEProject
from hpm_platform.ui.quick_solver import solve_project
from hpm_platform.ui.pareto import run_pareto_study

project = CAEProject.load_yaml(ROOT / 'configs' / 'cae_project_v12.yaml')
project

# %%
result = solve_project(project)
result.metrics_frame()

# %%
result.object_metrics

# %%
study = run_pareto_study(project, points=7, fast_mode=True)
study.records

# %% [markdown]
# 交互式 CAE 工作台入口：`python run_ui_v12.py`。完整验收报告位于 `outputs_v12_ui/v12_acceptance_report.html`。
